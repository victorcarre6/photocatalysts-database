# %%
import requests
from bs4 import BeautifulSoup
import csv

# %%
base_url = "https://photochemcad.com/databases"

urls_to_scrape = [
    "/common-compounds/aromatic-hydrocarbons",
    "/common-compounds/heterocycles",  
    "/common-compounds/biomolecules",
    "/common-compounds/quinones",
    "/common-compounds/coumarins",
    "/common-compounds/acridines",
    "/common-compounds/azo-dyes",
    "/common-compounds/cyanine-dyes",
    "/common-compounds/arylmethane-dyes",
    "/common-compounds/perylenes",
    "/common-compounds/xanthenes",
    "/common-compounds/miscellaneous-dyes",
    "/common-compounds/dipyrrins",
    "/common-compounds/porphyrins",
    "/common-compounds/oligopyrroles",
    "/common-compounds/phthalocyanines",
    "/common-compounds/chlorins-bacteriochlorins",
    "/naturally-derived-porphyrins",
    "/natural-chlorophylls",
    "/tolyporphins",
    "/flavonoids",
    "/phyllobilins",
    "/open-chain-tetrapyrrole"
]

# %%
# Fonction pour obtenir les URLs des composés à partir d'une page donnée
def get_compound_urls_from_page(url):
    print(f"Requesting URL: {url}")
    response = requests.get(url)

    if response.status_code != 200:
        print(f"Failed to retrieve {url} (Status code: {response.status_code})")
        return []

    soup = BeautifulSoup(response.text, 'html.parser')

    # Trouver tous les liens pertinents (liens vers les pages des molécules)
    compound_links = soup.find_all('a', href=True)
    print(f"Found {len(compound_links)} links on {url}")

    compound_urls = []
    for link in compound_links:
        href = link['href']
        
        # Si le lien est relatif, ajouter le base_url
        if not href.startswith('http'):
            full_url = base_url + href if href.startswith('/') else href
        else:
            full_url = href

        # Filtrer les liens pertinents
        if "common-compounds" in full_url:
            compound_urls.append(full_url)

    return compound_urls

# %%
# Fonction principale pour scraper toutes les pages
def main():
    all_urls = []

    # Pour chaque page spécifiée dans urls_to_scrape
    for url in urls_to_scrape:
        # Si l'URL est relative, la compléter avec le base_url
        full_url = url if url.startswith('http') else base_url + url
        print(f"Scraping {full_url}...")

        # Extraire les URLs des composés sur cette page
        compound_urls = get_compound_urls_from_page(full_url)
        all_urls.extend(compound_urls)

    # Vérification si des URLs ont été récupérées et écriture dans un fichier CSV
    if not all_urls:
        print("Aucun lien de molécule trouvé.")
        return

    with open('compound_urls.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["Compound URL"])  # En-tête
        for url in all_urls:
            writer.writerow([url])  # Ajouter chaque URL au CSV

if __name__ == "__main__":
    main()

# %%
# Fonction pour extraire les données d'une molécule
def extract_molecule_data(compound_url):
    print(f"Extracting data from {compound_url}")
    response = requests.get(compound_url)

    if response.status_code != 200:
        print(f"Failed to retrieve {compound_url} (Status code: {response.status_code})")
        return None

    soup = BeautifulSoup(response.text, 'html.parser')

    # Extraire tous les tableaux sur la page
    data_tables = soup.find_all('table')
    if not data_tables:
        print(f"Aucune table trouvée pour {compound_url}")
        return None

    # Dictionnaire pour stocker les données
    data = {
        "PhotochemCAD ID": "",
        "Compound Category": "",
        "Name": "",
        "Synonym": "",
        "CAS": "",
        "Source": "",
        "Absorption Wavelength": "",
        "Absorption epsilon": "",
        "Absorption coefficient": "",
        "Quantum Yield": "",
        "Solvent": "",
    }

    # Remplissage des données à partir des tableaux
    for table in data_tables:
        rows = table.find_all('tr')
        for row in rows:
            header_cell = row.find('th')
            data_cell = row.find('td')

            if header_cell and data_cell:
                key = header_cell.text.strip()
                value = data_cell.text.strip()

                # Vérifier si c'est une valeur qu'on veut
                if key in data:
                    # Gérer les liens (ex. source ou fichiers)
                    if data_cell.find('a'):
                        link = data_cell.find('a').get('href')
                        # Compléter l'URL si nécessaire
                        if link.startswith("/"):
                            value = f"https://photochemcad.com{link}"
                    data[key] = value

    return data

# %%
# Fonction principale pour lire les URLs et extraire les informations
def main():
    # Lire les URLs à partir du fichier CSV
    compound_urls = []
    with open('compound_urls.csv', 'r', encoding='utf-8') as csvfile:
        reader = csv.reader(csvfile)
        next(reader)  # Ignorer l'en-tête
        compound_urls = [row[0].replace('/databases/databases/', '/databases/') for row in reader]

    # Liste pour stocker les données de toutes les molécules
    all_molecule_data = []

    # Extraire les informations pour chaque URL
    for url in compound_urls:
        data = extract_molecule_data(url)
        if data:
            all_molecule_data.append(data)

    # Vérifier si des données ont été extraites et écrire dans un fichier CSV
    if not all_molecule_data:
        print("Aucune donnée n'a été extraite.")
        return

    with open('molecule_data.csv', 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = [
            "PhotochemCAD ID", "Compound Category", "Name", "Synonym", "CAS", "Source",
            "Absorption Wavelength", "Absorption epsilon", "Absorption coefficient", 
            "Quantum Yield", "Solvent"
        ]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()  # Écriture de l'en-tête
        writer.writerows(all_molecule_data)  # Écriture des données

    print("Extraction terminée. Les données sont enregistrées dans 'molecule_data.csv'.")

if __name__ == "__main__":
    main()
# Out:
# Extracting data from https://photochemcad.com/databases/common-compounds
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds
# Extracting data from https://photochemcad.com/databases/spectra-viewers/common-compounds
# Extracting data from https://photochemcad.com/databases/common-compounds
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/benzene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/toluene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/o-xylene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/m-xylene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/p-xylene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/mesitylene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/durene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/pentamethylbenzene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/hexamethylbenzene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/phenol
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/anisole
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/benzonitrile
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/benzaldehyde
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/benzoic-acid
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/acetophenone
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/aniline
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/nn-dimethyl-aniline
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/phenylhydrazine-hydrochloride
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/chlorobenzene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/iodobenzene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/nitrobenzene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/styrene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/phenylacetylene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/14-diethynylbenzene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/phenylpropargyl-aldehyde
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/phenylboronic-acid
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/vanillin
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/3-hydroxyacetophenone
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/ethyl-4-dimethylaminobenzoate
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/gallacetophenone
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/terephthalic-acid
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/p-phenylenediamine
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/tetraphenylmethane
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/n-phenylbenzylamine
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/trans-chalcone
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/benzophenone
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/44-dihydroxybenzophenone
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/diethyl-phthalate
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/1245-tetracyanobenzene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/hexafluorobenzene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/ferrocene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/benzene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/toluene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/o-xylene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/m-xylene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/p-xylene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/mesitylene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/durene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/pentamethylbenzene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/hexamethylbenzene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/phenol
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/anisole
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/benzonitrile
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/benzaldehyde
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/benzoic-acid
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/acetophenone
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/aniline
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/nn-dimethyl-aniline
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/phenylhydrazine-hydrochloride
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/chlorobenzene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/iodobenzene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/nitrobenzene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/styrene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/phenylacetylene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/14-diethynylbenzene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/phenylpropargyl-aldehyde
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/phenylboronic-acid
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/vanillin
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/3-hydroxyacetophenone
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/ethyl-4-dimethylaminobenzoate
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/gallacetophenone
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/terephthalic-acid
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/p-phenylenediamine
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/tetraphenylmethane
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/n-phenylbenzylamine
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/trans-chalcone
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/benzophenone
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/44-dihydroxybenzophenone
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/diethyl-phthalate
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/1245-tetracyanobenzene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/hexafluorobenzene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons/ferrocene
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons
# Extracting data from https://photochemcad.com/databases/common-compounds/oligophenylenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligophenylenes
# Extracting data from https://photochemcad.com/databases/common-compounds/polycyclic-aromatic-hydrocarbons
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/polycyclic-aromatic-hydrocarbons
# Extracting data from https://photochemcad.com/databases/common-compounds/polyenes-polyynes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/polyenes-polyynes
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/heterocycles
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/biomolecules
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/quinones
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/coumarins
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/acridines
# Extracting data from https://photochemcad.com/databases/common-compounds/azo-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/azo-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/cyanine-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/cyanine-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/arylmethane-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/arylmethane-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/perylenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/perylenes
# Extracting data from https://photochemcad.com/databases/common-compounds/xanthenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/xanthenes
# Extracting data from https://photochemcad.com/databases/common-compounds/miscellaneous-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/miscellaneous-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/dipyrrins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/dipyrrins
# Extracting data from https://photochemcad.com/databases/common-compounds/porphyrins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/porphyrins
# Extracting data from https://photochemcad.com/databases/common-compounds/oligopyrroles
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligopyrroles
# Extracting data from https://photochemcad.com/databases/common-compounds/phthalocyanines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/phthalocyanines
# Extracting data from https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Extracting data from https://photochemcad.com/databases/common-compounds
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds
# Extracting data from https://photochemcad.com/databases/spectra-viewers/common-compounds
# Extracting data from https://photochemcad.com/databases/common-compounds
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/pyridine
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/pyridine-n-oxide
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/2-acetylpyridine
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/4-dimethylaminopyridine
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/4-4-nitrobenzylpyridine
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/135-triazine
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/phthalimide
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/22-bipyridine
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/44-bipyridine
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/quinoline
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/8-quinoline-carboxylic-acid
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/3-quinoline-carboxaldehyde
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/benzothiazole
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/benzotriazole
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/2-methylbenzoxazole
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/pyrrole
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/pyrrole-2-carboxaldehyde
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/thiazole-orange
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/thioflavin-t
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/tris22-bipyridylrutheniumii
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/4-chloro-7-nitrobenzofurazan
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/7-benzylamino-4-nitrobenz-2-oxa-13-diazole
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/carbostyril-124
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/quinoline-yellow
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/235-triphenyltetrazolium-chloride
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/quinine-sulfate
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/pyridine
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/pyridine-n-oxide
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/2-acetylpyridine
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/4-dimethylaminopyridine
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/4-4-nitrobenzylpyridine
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/135-triazine
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/phthalimide
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/22-bipyridine
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/44-bipyridine
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/quinoline
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/8-quinoline-carboxylic-acid
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/3-quinoline-carboxaldehyde
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/benzothiazole
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/benzotriazole
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/2-methylbenzoxazole
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/pyrrole
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/pyrrole-2-carboxaldehyde
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/thiazole-orange
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/thioflavin-t
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/tris22-bipyridylrutheniumii
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/4-chloro-7-nitrobenzofurazan
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/7-benzylamino-4-nitrobenz-2-oxa-13-diazole
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/carbostyril-124
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/quinoline-yellow
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/235-triphenyltetrazolium-chloride
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles/quinine-sulfate
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons
# Extracting data from https://photochemcad.com/databases/common-compounds/oligophenylenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligophenylenes
# Extracting data from https://photochemcad.com/databases/common-compounds/polycyclic-aromatic-hydrocarbons
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/polycyclic-aromatic-hydrocarbons
# Extracting data from https://photochemcad.com/databases/common-compounds/polyenes-polyynes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/polyenes-polyynes
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/heterocycles
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/biomolecules
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/quinones
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/coumarins
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/acridines
# Extracting data from https://photochemcad.com/databases/common-compounds/azo-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/azo-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/cyanine-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/cyanine-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/arylmethane-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/arylmethane-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/perylenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/perylenes
# Extracting data from https://photochemcad.com/databases/common-compounds/xanthenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/xanthenes
# Extracting data from https://photochemcad.com/databases/common-compounds/miscellaneous-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/miscellaneous-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/dipyrrins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/dipyrrins
# Extracting data from https://photochemcad.com/databases/common-compounds/porphyrins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/porphyrins
# Extracting data from https://photochemcad.com/databases/common-compounds/oligopyrroles
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligopyrroles
# Extracting data from https://photochemcad.com/databases/common-compounds/phthalocyanines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/phthalocyanines
# Extracting data from https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Extracting data from https://photochemcad.com/databases/common-compounds
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds
# Extracting data from https://photochemcad.com/databases/spectra-viewers/common-compounds
# Extracting data from https://photochemcad.com/databases/common-compounds
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/l-alanine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/l-phenylalanine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/l-tyrosine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/l-histidine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/l-tryptophan
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/adenine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/guanine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/cytosine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/thymine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/uracil
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/2-amino-4-methylpyrimidine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/24-dihydroxy-6-methylpyrimidine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/d-salicin
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/riboflavin
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/l-ascorbic-acid
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/dl-alpha-tocopherol
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/vitamin-k1
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/folic-acid
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/l-alanine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/l-phenylalanine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/l-tyrosine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/l-histidine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/l-tryptophan
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/adenine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/guanine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/cytosine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/thymine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/uracil
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/2-amino-4-methylpyrimidine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/24-dihydroxy-6-methylpyrimidine
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/d-salicin
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/riboflavin
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/l-ascorbic-acid
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/dl-alpha-tocopherol
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/vitamin-k1
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules/folic-acid
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons
# Extracting data from https://photochemcad.com/databases/common-compounds/oligophenylenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligophenylenes
# Extracting data from https://photochemcad.com/databases/common-compounds/polycyclic-aromatic-hydrocarbons
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/polycyclic-aromatic-hydrocarbons
# Extracting data from https://photochemcad.com/databases/common-compounds/polyenes-polyynes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/polyenes-polyynes
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/heterocycles
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/biomolecules
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/quinones
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/coumarins
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/acridines
# Extracting data from https://photochemcad.com/databases/common-compounds/azo-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/azo-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/cyanine-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/cyanine-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/arylmethane-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/arylmethane-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/perylenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/perylenes
# Extracting data from https://photochemcad.com/databases/common-compounds/xanthenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/xanthenes
# Extracting data from https://photochemcad.com/databases/common-compounds/miscellaneous-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/miscellaneous-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/dipyrrins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/dipyrrins
# Extracting data from https://photochemcad.com/databases/common-compounds/porphyrins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/porphyrins
# Extracting data from https://photochemcad.com/databases/common-compounds/oligopyrroles
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligopyrroles
# Extracting data from https://photochemcad.com/databases/common-compounds/phthalocyanines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/phthalocyanines
# Extracting data from https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Extracting data from https://photochemcad.com/databases/common-compounds
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds
# Extracting data from https://photochemcad.com/databases/spectra-viewers/common-compounds
# Extracting data from https://photochemcad.com/databases/common-compounds
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/14-benzoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/hydroquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/2356-tetrachloro-14-benzoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/tetrachlorohydroquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/2356-tetramethyl-14-benzoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/23-dichloro-56-dicyano-14-benzoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/3456-tetrachloro-12-benzoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/25-diphenyl-14-benzoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/25-di-tert-butyl-14-benzoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/tetracyanoethylene
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/7788-tetracyanoquinodimethane
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/14-naphthoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/14-naphthoquinone-2-sulfonic-acid-potassium-salt
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/23-dichloro-14-naphthoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/2-methyl-14-naphthoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/910-phenanthrenequinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/12-naphthoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/12-naphthoquinone-4-sulfonic-acid-sodium-salt
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/910-anthraquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/alizarin
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/alizarin-red-s
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/14-anthraquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/512-naphthacenequinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/613-pentacenequinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/14-benzoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/hydroquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/2356-tetrachloro-14-benzoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/tetrachlorohydroquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/2356-tetramethyl-14-benzoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/23-dichloro-56-dicyano-14-benzoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/3456-tetrachloro-12-benzoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/25-diphenyl-14-benzoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/25-di-tert-butyl-14-benzoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/tetracyanoethylene
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/7788-tetracyanoquinodimethane
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/14-naphthoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/14-naphthoquinone-2-sulfonic-acid-potassium-salt
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/23-dichloro-14-naphthoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/2-methyl-14-naphthoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/910-phenanthrenequinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/12-naphthoquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/12-naphthoquinone-4-sulfonic-acid-sodium-salt
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/910-anthraquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/alizarin
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/alizarin-red-s
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/14-anthraquinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/512-naphthacenequinone
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones/613-pentacenequinone
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons
# Extracting data from https://photochemcad.com/databases/common-compounds/oligophenylenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligophenylenes
# Extracting data from https://photochemcad.com/databases/common-compounds/polycyclic-aromatic-hydrocarbons
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/polycyclic-aromatic-hydrocarbons
# Extracting data from https://photochemcad.com/databases/common-compounds/polyenes-polyynes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/polyenes-polyynes
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/heterocycles
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/biomolecules
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/quinones
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/coumarins
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/acridines
# Extracting data from https://photochemcad.com/databases/common-compounds/azo-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/azo-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/cyanine-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/cyanine-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/arylmethane-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/arylmethane-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/perylenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/perylenes
# Extracting data from https://photochemcad.com/databases/common-compounds/xanthenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/xanthenes
# Extracting data from https://photochemcad.com/databases/common-compounds/miscellaneous-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/miscellaneous-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/dipyrrins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/dipyrrins
# Extracting data from https://photochemcad.com/databases/common-compounds/porphyrins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/porphyrins
# Extracting data from https://photochemcad.com/databases/common-compounds/oligopyrroles
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligopyrroles
# Extracting data from https://photochemcad.com/databases/common-compounds/phthalocyanines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/phthalocyanines
# Extracting data from https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Extracting data from https://photochemcad.com/databases/common-compounds
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds
# Extracting data from https://photochemcad.com/databases/spectra-viewers/common-compounds
# Extracting data from https://photochemcad.com/databases/common-compounds
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/coumarin
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/4-hydroxycoumarin
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/7-hydroxycoumarin
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/7-hydroxy-4-trifluoromethylcoumarin
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/7-methoxycoumarin-4-acetic-acid
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/coumarin-1
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/coumarin-6
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/coumarin-7
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/coumarin-30
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/coumarin-151
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/coumarin-314
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/coumarin-343
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/calcein-blue
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/urolithin-b
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/coumarin
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/4-hydroxycoumarin
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/7-hydroxycoumarin
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/7-hydroxy-4-trifluoromethylcoumarin
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/7-methoxycoumarin-4-acetic-acid
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/coumarin-1
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/coumarin-6
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/coumarin-7
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/coumarin-30
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/coumarin-151
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/coumarin-314
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/coumarin-343
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/calcein-blue
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins/urolithin-b
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons
# Extracting data from https://photochemcad.com/databases/common-compounds/oligophenylenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligophenylenes
# Extracting data from https://photochemcad.com/databases/common-compounds/polycyclic-aromatic-hydrocarbons
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/polycyclic-aromatic-hydrocarbons
# Extracting data from https://photochemcad.com/databases/common-compounds/polyenes-polyynes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/polyenes-polyynes
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/heterocycles
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/biomolecules
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/quinones
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/coumarins
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/acridines
# Extracting data from https://photochemcad.com/databases/common-compounds/azo-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/azo-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/cyanine-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/cyanine-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/arylmethane-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/arylmethane-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/perylenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/perylenes
# Extracting data from https://photochemcad.com/databases/common-compounds/xanthenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/xanthenes
# Extracting data from https://photochemcad.com/databases/common-compounds/miscellaneous-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/miscellaneous-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/dipyrrins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/dipyrrins
# Extracting data from https://photochemcad.com/databases/common-compounds/porphyrins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/porphyrins
# Extracting data from https://photochemcad.com/databases/common-compounds/oligopyrroles
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligopyrroles
# Extracting data from https://photochemcad.com/databases/common-compounds/phthalocyanines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/phthalocyanines
# Extracting data from https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Extracting data from https://photochemcad.com/databases/common-compounds
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds
# Extracting data from https://photochemcad.com/databases/spectra-viewers/common-compounds
# Extracting data from https://photochemcad.com/databases/common-compounds
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines/acridine
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines/proflavine-hydrochloride
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines/acridine-orange
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines/acridine-yellow-g
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines/acridone
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines/phenazine
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines/phenosafranin
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines/neutral-red
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines/janus-green-b
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines/phenothiazine
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines/thionin
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines/methylene-blue
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines/azure-ii
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines/toluidine-blue-o
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines/phenoxathiin
# ...
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligopyrroles
# Extracting data from https://photochemcad.com/databases/common-compounds/phthalocyanines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/phthalocyanines
# Extracting data from https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Extracting data from https://photochemcad.com/databases/common-compounds
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds
# Extracting data from https://photochemcad.com/databases/spectra-viewers/common-compounds
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons
# Extracting data from https://photochemcad.com/databases/common-compounds/oligophenylenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligophenylenes
# Extracting data from https://photochemcad.com/databases/common-compounds/polycyclic-aromatic-hydrocarbons
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/polycyclic-aromatic-hydrocarbons
# Extracting data from https://photochemcad.com/databases/common-compounds/polyenes-polyynes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/polyenes-polyynes
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/heterocycles
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/biomolecules
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/quinones
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/coumarins
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/acridines
# Extracting data from https://photochemcad.com/databases/common-compounds/azo-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/azo-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/cyanine-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/cyanine-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/arylmethane-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/arylmethane-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/perylenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/perylenes
# Extracting data from https://photochemcad.com/databases/common-compounds/xanthenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/xanthenes
# Extracting data from https://photochemcad.com/databases/common-compounds/miscellaneous-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/miscellaneous-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/dipyrrins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/dipyrrins
# Extracting data from https://photochemcad.com/databases/common-compounds/porphyrins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/porphyrins
# Extracting data from https://photochemcad.com/databases/common-compounds/oligopyrroles
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligopyrroles
# Extracting data from https://photochemcad.com/databases/common-compounds/phthalocyanines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/phthalocyanines
# Extracting data from https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Extracting data from https://photochemcad.com/databases/common-compounds
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds
# Extracting data from https://photochemcad.com/databases/spectra-viewers/common-compounds
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons
# Extracting data from https://photochemcad.com/databases/common-compounds/oligophenylenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligophenylenes
# Extracting data from https://photochemcad.com/databases/common-compounds/polycyclic-aromatic-hydrocarbons
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/polycyclic-aromatic-hydrocarbons
# Extracting data from https://photochemcad.com/databases/common-compounds/polyenes-polyynes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/polyenes-polyynes
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/heterocycles
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/biomolecules
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/quinones
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/coumarins
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/acridines
# Extracting data from https://photochemcad.com/databases/common-compounds/azo-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/azo-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/cyanine-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/cyanine-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/arylmethane-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/arylmethane-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/perylenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/perylenes
# Extracting data from https://photochemcad.com/databases/common-compounds/xanthenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/xanthenes
# Extracting data from https://photochemcad.com/databases/common-compounds/miscellaneous-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/miscellaneous-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/dipyrrins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/dipyrrins
# Extracting data from https://photochemcad.com/databases/common-compounds/porphyrins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/porphyrins
# Extracting data from https://photochemcad.com/databases/common-compounds/oligopyrroles
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligopyrroles
# Extracting data from https://photochemcad.com/databases/common-compounds/phthalocyanines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/phthalocyanines
# Extracting data from https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Extracting data from https://photochemcad.com/databases/common-compounds
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds
# Extracting data from https://photochemcad.com/databases/spectra-viewers/common-compounds
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons
# Extracting data from https://photochemcad.com/databases/common-compounds/oligophenylenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligophenylenes
# Extracting data from https://photochemcad.com/databases/common-compounds/polycyclic-aromatic-hydrocarbons
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/polycyclic-aromatic-hydrocarbons
# Extracting data from https://photochemcad.com/databases/common-compounds/polyenes-polyynes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/polyenes-polyynes
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/heterocycles
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/biomolecules
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/quinones
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/coumarins
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/acridines
# Extracting data from https://photochemcad.com/databases/common-compounds/azo-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/azo-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/cyanine-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/cyanine-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/arylmethane-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/arylmethane-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/perylenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/perylenes
# Extracting data from https://photochemcad.com/databases/common-compounds/xanthenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/xanthenes
# Extracting data from https://photochemcad.com/databases/common-compounds/miscellaneous-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/miscellaneous-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/dipyrrins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/dipyrrins
# Extracting data from https://photochemcad.com/databases/common-compounds/porphyrins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/porphyrins
# Extracting data from https://photochemcad.com/databases/common-compounds/oligopyrroles
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligopyrroles
# Extracting data from https://photochemcad.com/databases/common-compounds/phthalocyanines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/phthalocyanines
# Extracting data from https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Extracting data from https://photochemcad.com/databases/common-compounds
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds
# Extracting data from https://photochemcad.com/databases/spectra-viewers/common-compounds
# Extracting data from https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/aromatic-hydrocarbons
# Extracting data from https://photochemcad.com/databases/common-compounds/oligophenylenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligophenylenes
# Extracting data from https://photochemcad.com/databases/common-compounds/polycyclic-aromatic-hydrocarbons
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/polycyclic-aromatic-hydrocarbons
# Extracting data from https://photochemcad.com/databases/common-compounds/polyenes-polyynes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/polyenes-polyynes
# Extracting data from https://photochemcad.com/databases/common-compounds/heterocycles
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/heterocycles
# Extracting data from https://photochemcad.com/databases/common-compounds/biomolecules
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/biomolecules
# Extracting data from https://photochemcad.com/databases/common-compounds/quinones
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/quinones
# Extracting data from https://photochemcad.com/databases/common-compounds/coumarins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/coumarins
# Extracting data from https://photochemcad.com/databases/common-compounds/acridines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/acridines
# Extracting data from https://photochemcad.com/databases/common-compounds/azo-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/azo-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/cyanine-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/cyanine-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/arylmethane-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/arylmethane-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/perylenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/perylenes
# Extracting data from https://photochemcad.com/databases/common-compounds/xanthenes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/xanthenes
# Extracting data from https://photochemcad.com/databases/common-compounds/miscellaneous-dyes
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/miscellaneous-dyes
# Extracting data from https://photochemcad.com/databases/common-compounds/dipyrrins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/dipyrrins
# Extracting data from https://photochemcad.com/databases/common-compounds/porphyrins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/porphyrins
# Extracting data from https://photochemcad.com/databases/common-compounds/oligopyrroles
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/oligopyrroles
# Extracting data from https://photochemcad.com/databases/common-compounds/phthalocyanines
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/phthalocyanines
# Extracting data from https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Aucune table trouvée pour https://photochemcad.com/databases/common-compounds/chlorins-bacteriochlorins
# Extraction terminée. Les données sont enregistrées dans 'molecule_data.csv'.

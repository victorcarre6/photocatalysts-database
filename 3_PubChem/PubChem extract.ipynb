# %%
import pandas as pd
import pubchempy as pcp

# Chemin vers ton fichier CSV
input_csv = "photocompounds_database.csv"
output_csv = "photocompounds_database_pubchem.csv"

# Charger le fichier CSV
data = pd.read_csv(input_csv, sep=";")

# %%
# Colonnes à ajouter
new_columns = ["Molecular Weight", "Chemical Formula", "SMILES", 
               "H-Bond Donor Count", "H-Bond Acceptor Count", 
               "Solubility", "Melting Point", "Boiling Point", "pKa"]

# Ajouter les nouvelles colonnes si elles n'existent pas encore
for col in new_columns:
    if col not in data.columns:
        data[col] = ""

# Remplir les nouvelles colonnes
for index, row in data.iterrows():
    cas_number = row["CAS"]
    try:
        # Récupérer les informations depuis PubChem
        compound = pcp.get_compounds(cas_number, "name")
        if compound:
            comp = compound[0]
            data.at[index, "Molecular Weight"] = comp.molecular_weight
            data.at[index, "Chemical Formula"] = comp.molecular_formula
            data.at[index, "SMILES"] = comp.canonical_smiles
            data.at[index, "H-Bond Donor Count"] = comp.h_bond_donor_count
            data.at[index, "H-Bond Acceptor Count"] = comp.h_bond_acceptor_count
            
            # Extraire les propriétés supplémentaires
            properties = comp.to_dict()
            data.at[index, "Solubility"] = properties.get("Solubility", "")
            data.at[index, "Melting Point"] = properties.get("Melting Point", "")
            data.at[index, "Boiling Point"] = properties.get("Boiling Point", "")
            data.at[index, "pKa"] = properties.get("pKa", "")

            print(f"✅ Informations ajoutées pour le CAS {cas_number}")
        else:
            print(f"⚠️ Aucune information trouvée pour le CAS {cas_number}")
    except Exception as e:
        print(f"⚠️ Erreur pour le CAS {cas_number} : {e}")
# Out:
# ✅ Informations ajoutées pour le CAS 71-43-2
# ✅ Informations ajoutées pour le CAS 108-88-3
# ✅ Informations ajoutées pour le CAS 95-47-6
# ✅ Informations ajoutées pour le CAS 108-38-3
# ✅ Informations ajoutées pour le CAS 106-42-3
# ✅ Informations ajoutées pour le CAS 108-67-8
# ✅ Informations ajoutées pour le CAS 95-93-2
# ✅ Informations ajoutées pour le CAS 700-12-9
# ✅ Informations ajoutées pour le CAS 87-85-4
# ✅ Informations ajoutées pour le CAS 108-95-2
# ✅ Informations ajoutées pour le CAS 100-66-3
# ✅ Informations ajoutées pour le CAS 100-47-0
# ✅ Informations ajoutées pour le CAS 100-52-7
# ✅ Informations ajoutées pour le CAS 65-85-0
# ✅ Informations ajoutées pour le CAS 98-86-2
# ✅ Informations ajoutées pour le CAS 62-53-3
# ✅ Informations ajoutées pour le CAS 121-69-7
# ✅ Informations ajoutées pour le CAS 59-88-1
# ✅ Informations ajoutées pour le CAS 108-90-7
# ✅ Informations ajoutées pour le CAS 591-50-4
# ✅ Informations ajoutées pour le CAS 98-95-3
# ✅ Informations ajoutées pour le CAS 100-42-5
# ✅ Informations ajoutées pour le CAS 536-74-3
# ✅ Informations ajoutées pour le CAS 935-14-8
# ✅ Informations ajoutées pour le CAS 2579-22-8
# ✅ Informations ajoutées pour le CAS 98-80-6
# ✅ Informations ajoutées pour le CAS 121-33-5
# ✅ Informations ajoutées pour le CAS 121-71-1
# ✅ Informations ajoutées pour le CAS 10287-53-3
# ✅ Informations ajoutées pour le CAS 528-21-2
# ✅ Informations ajoutées pour le CAS 100-21-0
# ✅ Informations ajoutées pour le CAS 106-50-3
# ✅ Informations ajoutées pour le CAS 630-76-2
# ✅ Informations ajoutées pour le CAS 103-32-2
# ✅ Informations ajoutées pour le CAS 614-47-1
# ✅ Informations ajoutées pour le CAS 119-61-9
# ✅ Informations ajoutées pour le CAS 611-99-4
# ✅ Informations ajoutées pour le CAS 84-66-2
# ✅ Informations ajoutées pour le CAS 712-74-3
# ✅ Informations ajoutées pour le CAS 392-56-3
# ✅ Informations ajoutées pour le CAS 102-54-5
# ✅ Informations ajoutées pour le CAS 110-86-1
# ✅ Informations ajoutées pour le CAS 694-59-7
# ✅ Informations ajoutées pour le CAS 1122-62-9
# ✅ Informations ajoutées pour le CAS 1122-58-3
# ✅ Informations ajoutées pour le CAS 1083-48-3
# ✅ Informations ajoutées pour le CAS 290-87-9
# ✅ Informations ajoutées pour le CAS 85-41-6
# ✅ Informations ajoutées pour le CAS 366-18-7
# ✅ Informations ajoutées pour le CAS 553-26-4
# ✅ Informations ajoutées pour le CAS 91-22-5
# ✅ Informations ajoutées pour le CAS 86-59-9
# ✅ Informations ajoutées pour le CAS 13669-42-6
# ✅ Informations ajoutées pour le CAS 95-16-9
# ✅ Informations ajoutées pour le CAS 95-14-7
# ✅ Informations ajoutées pour le CAS 95-21-6
# ✅ Informations ajoutées pour le CAS 109-97-7
# ✅ Informations ajoutées pour le CAS 1003-29-8
# ✅ Informations ajoutées pour le CAS 107091-89-4
# ✅ Informations ajoutées pour le CAS 2390-54-7
# ✅ Informations ajoutées pour le CAS 65034-88-0
# ✅ Informations ajoutées pour le CAS 10199-89-0
# ✅ Informations ajoutées pour le CAS 18378-20-6
# ✅ Informations ajoutées pour le CAS 19840-99-4
# ✅ Informations ajoutées pour le CAS 8004-92-0
# ✅ Informations ajoutées pour le CAS 298-96-4
# ✅ Informations ajoutées pour le CAS 207671-44-1
# ✅ Informations ajoutées pour le CAS 56-41-7
# ✅ Informations ajoutées pour le CAS 63-91-2
# ✅ Informations ajoutées pour le CAS 60-18-4
# ✅ Informations ajoutées pour le CAS 71-00-1
# ✅ Informations ajoutées pour le CAS 73-22-3
# ✅ Informations ajoutées pour le CAS 73-24-5
# ✅ Informations ajoutées pour le CAS 73-40-5
# ✅ Informations ajoutées pour le CAS 71-30-7
# ✅ Informations ajoutées pour le CAS 65-71-4
# ✅ Informations ajoutées pour le CAS 66-22-8
# ✅ Informations ajoutées pour le CAS 108-52-1
# ✅ Informations ajoutées pour le CAS 626-48-2
# ✅ Informations ajoutées pour le CAS 138-52-3
# ✅ Informations ajoutées pour le CAS 83-88-5
# ✅ Informations ajoutées pour le CAS 50-81-7
# ✅ Informations ajoutées pour le CAS 10191-41-0
# ✅ Informations ajoutées pour le CAS 84-80-0
# ✅ Informations ajoutées pour le CAS 59-30-3
# ✅ Informations ajoutées pour le CAS 106-51-4
# ✅ Informations ajoutées pour le CAS 123-31-9
# ✅ Informations ajoutées pour le CAS 118-75-2
# ✅ Informations ajoutées pour le CAS 87-87-6
# ✅ Informations ajoutées pour le CAS 527-17-3
# ✅ Informations ajoutées pour le CAS 84-58-2
# ✅ Informations ajoutées pour le CAS 2435-53-2
# ✅ Informations ajoutées pour le CAS 844-51-9
# ✅ Informations ajoutées pour le CAS 2460-77-7
# ✅ Informations ajoutées pour le CAS 670-54-2
# ✅ Informations ajoutées pour le CAS 1518-16-7
# ✅ Informations ajoutées pour le CAS 130-15-4
# ✅ Informations ajoutées pour le CAS 34169-62-5
# ✅ Informations ajoutées pour le CAS 117-80-6
# ✅ Informations ajoutées pour le CAS 58-27-5
# ✅ Informations ajoutées pour le CAS 84-11-7
# ✅ Informations ajoutées pour le CAS 524-42-5
# ✅ Informations ajoutées pour le CAS 521-24-4
# ✅ Informations ajoutées pour le CAS 84-65-1
# ✅ Informations ajoutées pour le CAS 72-48-0
# ✅ Informations ajoutées pour le CAS 130-22-3
# ✅ Informations ajoutées pour le CAS 635-12-1
# ✅ Informations ajoutées pour le CAS 1090-13-7
# ✅ Informations ajoutées pour le CAS 3029-32-1
# ✅ Informations ajoutées pour le CAS 91-64-5
# ✅ Informations ajoutées pour le CAS 1076-38-6
# ✅ Informations ajoutées pour le CAS 93-35-6
# ✅ Informations ajoutées pour le CAS 575-03-1
# ✅ Informations ajoutées pour le CAS 62935-72-2
# ✅ Informations ajoutées pour le CAS 91-44-1
# ✅ Informations ajoutées pour le CAS 38215-36-0
# ✅ Informations ajoutées pour le CAS 27425-55-4
# ✅ Informations ajoutées pour le CAS 41044-12-6
# ✅ Informations ajoutées pour le CAS 53518-15-3
# ✅ Informations ajoutées pour le CAS 55804-66-5
# ✅ Informations ajoutées pour le CAS 55804-65-4
# ✅ Informations ajoutées pour le CAS 54375-47-2
# ✅ Informations ajoutées pour le CAS 1139-83-9
# ✅ Informations ajoutées pour le CAS 260-94-6
# ✅ Informations ajoutées pour le CAS 952-23-8
# ✅ Informations ajoutées pour le CAS 65-61-2
# ✅ Informations ajoutées pour le CAS 135-49-9
# ✅ Informations ajoutées pour le CAS 578-95-0
# ✅ Informations ajoutées pour le CAS 92-82-0
# ✅ Informations ajoutées pour le CAS 81-93-6
# ✅ Informations ajoutées pour le CAS 553-24-2
# ✅ Informations ajoutées pour le CAS 2869-83-2
# ✅ Informations ajoutées pour le CAS 92-84-2
# ✅ Informations ajoutées pour le CAS 26754-93-8
# ✅ Informations ajoutées pour le CAS 61-73-4
# ✅ Informations ajoutées pour le CAS 37247-10-2
# ✅ Informations ajoutées pour le CAS 92-31-9
# ✅ Informations ajoutées pour le CAS 262-20-4
# ✅ Informations ajoutées pour le CAS 135-67-1
# ✅ Informations ajoutées pour le CAS 24796-94-9
# ✅ Informations ajoutées pour le CAS 41830-80-2
# ✅ Informations ajoutées pour le CAS 7385-67-3
# ✅ Informations ajoutées pour le CAS 53340-16-2
# ✅ Informations ajoutées pour le CAS 62669-60-7
# ✅ Informations ajoutées pour le CAS 103-33-3
# ✅ Informations ajoutées pour le CAS 493-52-7
# ✅ Informations ajoutées pour le CAS 547-58-0
# ✅ Informations ajoutées pour le CAS 1936-15-8
# ✅ Informations ajoutées pour le CAS 633-96-5
# ✅ Informations ajoutées pour le CAS 1658-56-6
# ✅ Informations ajoutées pour le CAS 842-07-9
# ✅ Informations ajoutées pour le CAS 3118-97-6
# ✅ Informations ajoutées pour le CAS 1681-60-3
# ✅ Informations ajoutées pour le CAS 3734-67-6
# ✅ Informations ajoutées pour le CAS 3567-69-9
# ✅ Informations ajoutées pour le CAS 3861-73-2
# ✅ Informations ajoutées pour le CAS 85-86-9
# ✅ Informations ajoutées pour le CAS 85-83-6
# ✅ Informations ajoutées pour le CAS 1064-48-8
# ✅ Informations ajoutées pour le CAS 6226-79-5
# ✅ Informations ajoutées pour le CAS 573-58-0
# ✅ Informations ajoutées pour le CAS 992-59-6
# ✅ Informations ajoutées pour le CAS 314-13-6
# ✅ Informations ajoutées pour le CAS 977-96-8
# ✅ Informations ajoutées pour le CAS 605-91-4
# ✅ Informations ajoutées pour le CAS 14187-31-6
# ✅ Informations ajoutées pour le CAS 4727-49-5
# ✅ Informations ajoutées pour le CAS 4727-50-8
# ✅ Informations ajoutées pour le CAS 18300-31-7
# ✅ Informations ajoutées pour le CAS 905-96-4
# ✅ Informations ajoutées pour le CAS 14806-50-9
# ✅ Informations ajoutées pour le CAS 15185-43-0
# ✅ Informations ajoutées pour le CAS 14696-39-0
# ✅ Informations ajoutées pour le CAS 17094-16-5
# ⚠️ Aucune information trouvée pour le CAS 15185-47-4
# ✅ Informations ajoutées pour le CAS 3599-32-4
# ✅ Informations ajoutées pour le CAS 905-97-5
# ✅ Informations ajoutées pour le CAS 514-73-8
# ✅ Informations ajoutées pour le CAS 3071-70-3
# ✅ Informations ajoutées pour le CAS 62796-23-0
# ✅ Informations ajoutées pour le CAS 51325-91-8
# ✅ Informations ajoutées pour le CAS 7423-31-6
# ✅ Informations ajoutées pour le CAS 2465-27-2
# ✅ Informations ajoutées pour le CAS 2437-29-8
# ✅ Informations ajoutées pour le CAS 548-62-9
# ✅ Informations ajoutées pour le CAS 632-99-5
# ✅ Informations ajoutées pour le CAS 8004-87-3
# ✅ Informations ajoutées pour le CAS 82-94-0
# ✅ Informations ajoutées pour le CAS 28983-56-4
# ✅ Informations ajoutées pour le CAS 77-09-8
# ✅ Informations ajoutées pour le CAS 143-74-8
# ✅ Informations ajoutées pour le CAS 1733-12-6
# ✅ Informations ajoutées pour le CAS 76-61-9
# ✅ Informations ajoutées pour le CAS 198-55-0
# ✅ Informations ajoutées pour le CAS 165550-61-8
# ⚠️ Aucune information trouvée pour le CAS RRN 9309914
# ⚠️ Aucune information trouvée pour le CAS 468083-01-4
# ✅ Informations ajoutées pour le CAS 83054-80-2
# ⚠️ Aucune information trouvée pour le CAS 05/07/2321
# ✅ Informations ajoutées pour le CAS 76-54-0
# ✅ Informations ajoutées pour le CAS 6262-21-1
# ✅ Informations ajoutées pour le CAS 548-24-3
# ⚠️ Aucune information trouvée pour le CAS 17372-87-1
# ⚠️ Aucune information trouvée pour le CAS 18472-87-2
# ✅ Informations ajoutées pour le CAS 16423-68-0
# ✅ Informations ajoutées pour le CAS 11121-48-5
# ✅ Informations ajoutées pour le CAS 161265-03-8
# ✅ Informations ajoutées pour le CAS 62669-70-9
# ✅ Informations ajoutées pour le CAS 81-88-9
# ✅ Informations ajoutées pour le CAS 3520-42-1
# ✅ Informations ajoutées pour le CAS 989-38-8
# ⚠️ Aucune information trouvée pour le CAS 41175-43-3 (116450-56-7)
# ✅ Informations ajoutées pour le CAS 60311-02-6
# ✅ Informations ajoutées pour le CAS 1091-85-6
# ✅ Informations ajoutées pour le CAS 67769-47-5
# ✅ Informations ajoutées pour le CAS 36322-90-4
# ✅ Informations ajoutées pour le CAS 4045-44-7
# ✅ Informations ajoutées pour le CAS 1239-45-8
# ✅ Informations ajoutées pour le CAS 28718-90-3
# ✅ Informations ajoutées pour le CAS 23491-45-4
# ⚠️ Aucune information trouvée pour le CAS 43134-09-4
# ✅ Informations ajoutées pour le CAS 133039-73-3
# ✅ Informations ajoutées pour le CAS 18766-66-0
# ✅ Informations ajoutées pour le CAS 7659-95-2
# ✅ Informations ajoutées pour le CAS 153-18-4
# ✅ Informations ajoutées pour le CAS 520-26-3
# ✅ Informations ajoutées pour le CAS 107798-98-1
# ⚠️ Aucune information trouvée pour le CAS 118762-53-1
# ⚠️ Aucune information trouvée pour le CAS 865479-43-2
# ⚠️ Aucune information trouvée pour le CAS RRN 8641167
# ⚠️ Aucune information trouvée pour le CAS RRN 9294810
# ⚠️ Aucune information trouvée pour le CAS RRN 11327052
# ⚠️ Aucune information trouvée pour le CAS RRN 11327059
# ✅ Informations ajoutées pour le CAS 101-60-0
# ⚠️ Aucune information trouvée pour le CAS RRN 1226935
# ⚠️ Aucune information trouvée pour le CAS RRN 1226937
# ✅ Informations ajoutées pour le CAS 2683-82-1
# ✅ Informations ajoutées pour le CAS 20910-35-4
# ✅ Informations ajoutées pour le CAS 14409-63-3
# ✅ Informations ajoutées pour le CAS 17632-18-7
# ✅ Informations ajoutées pour le CAS 917-23-7
# ⚠️ Aucune information trouvée pour le CAS 14640-21-2
# ✅ Informations ajoutées pour le CAS 14074-80-7
# ✅ Informations ajoutées pour le CAS 56396-12-4
# ⚠️ Aucune information trouvée pour le CAS RNN 8608739
# ⚠️ Aucune information trouvée pour le CAS RNN 4648207
# ✅ Informations ajoutées pour le CAS 14527-51-6
# ✅ Informations ajoutées pour le CAS 52199-35-6
# ✅ Informations ajoutées pour le CAS 37083-37-7
# ✅ Informations ajoutées pour le CAS 25440-14-6
# ⚠️ Aucune information trouvée pour le CAS RNN 10319450
# ⚠️ Erreur pour le CAS nan : 'float' object is not iterable
# ⚠️ Erreur pour le CAS nan : 'float' object is not iterable
# ✅ Informations ajoutées pour le CAS 5522-66-7
# ✅ Informations ajoutées pour le CAS 15489-90-4
# ✅ Informations ajoutées pour le CAS 52952-31-5
# ⚠️ Aucune information trouvée pour le CAS RNN 10238035
# ⚠️ Aucune information trouvée pour le CAS RNN 10238613
# ⚠️ Aucune information trouvée pour le CAS RNN 10238614
# ⚠️ Erreur pour le CAS nan : 'float' object is not iterable
# ⚠️ Erreur pour le CAS nan : 'float' object is not iterable
# ⚠️ Erreur pour le CAS nan : 'float' object is not iterable
# ⚠️ Erreur pour le CAS nan : 'float' object is not iterable
# ⚠️ Erreur pour le CAS nan : 'float' object is not iterable
# ⚠️ Aucune information trouvée pour le CAS RNN 8824349
# ⚠️ Aucune information trouvée pour le CAS RNN 8824926
# ⚠️ Aucune information trouvée pour le CAS RNN 8755729
# ✅ Informations ajoutées pour le CAS 246231-45-8
# ⚠️ Aucune information trouvée pour le CAS 262280-80-8
# ⚠️ Aucune information trouvée pour le CAS RNN 7345536
# ✅ Informations ajoutées pour le CAS 635-65-4
# ✅ Informations ajoutées pour le CAS 10035-62-8
# ✅ Informations ajoutées pour le CAS 68-19-9
# ✅ Informations ajoutées pour le CAS 574-93-6
# ✅ Informations ajoutées pour le CAS 1661-03-6
# ✅ Informations ajoutées pour le CAS 132-16-1
# ✅ Informations ajoutées pour le CAS 14320-04-8
# ✅ Informations ajoutées pour le CAS 116453-73-7
# ⚠️ Aucune information trouvée pour le CAS 35984-93-1
# ✅ Informations ajoutées pour le CAS 39001-65-5
# ✅ Informations ajoutées pour le CAS 105528-25-4
# ✅ Informations ajoutées pour le CAS 58687-99-3
# ✅ Informations ajoutées pour le CAS 64987-70-8
# ✅ Informations ajoutées pour le CAS 36530-06-0
# ✅ Informations ajoutées pour le CAS 479-61-8
# ✅ Informations ajoutées pour le CAS 519-62-0
# ✅ Informations ajoutées pour le CAS 15664-29-6
# ✅ Informations ajoutées pour le CAS 24533-72-0
# ✅ Informations ajoutées pour le CAS 6453-67-4
# ✅ Informations ajoutées pour le CAS 19660-77-6
# ✅ Informations ajoutées pour le CAS 25465-77-4
# ⚠️ Aucune information trouvée pour le CAS 2669-65-0
# ⚠️ Aucune information trouvée pour le CAS RNN 8601239
# ⚠️ Aucune information trouvée pour le CAS RNN 8606740
# ⚠️ Aucune information trouvée pour le CAS RNN 8606739
# ⚠️ Aucune information trouvée pour le CAS RNN 9374284
# ⚠️ Aucune information trouvée pour le CAS RNN 9379026
# ⚠️ Aucune information trouvée pour le CAS RNN 9379028
# ⚠️ Aucune information trouvée pour le CAS RNN 9379029
# ✅ Informations ajoutées pour le CAS 17499-98-8
# ✅ Informations ajoutées pour le CAS 623-26-7
# ✅ Informations ajoutées pour le CAS 3029-30-9
# ✅ Informations ajoutées pour le CAS 1217-45-4
# ✅ Informations ajoutées pour le CAS 119-61-9
# ✅ Informations ajoutées pour le CAS 90-94-8
# ✅ Informations ajoutées pour le CAS 486-25-9
# ✅ Informations ajoutées pour le CAS 90-47-1
# ✅ Informations ajoutées pour le CAS 492-22-8
# ✅ Informations ajoutées pour le CAS 118-75-2
# ✅ Informations ajoutées pour le CAS 84-65-1
# ✅ Informations ajoutées pour le CAS 15959-35-0
# ✅ Informations ajoutées pour le CAS 47659-08-5
# ✅ Informations ajoutées pour le CAS 18342-83-1
# ✅ Informations ajoutées pour le CAS 47659-14-3
# ✅ Informations ajoutées pour le CAS 21979-19-1
# ✅ Informations ajoutées pour le CAS 46176-64-1
# ✅ Informations ajoutées pour le CAS 26456-05-3
# ✅ Informations ajoutées pour le CAS 36519-61-6
# ✅ Informations ajoutées pour le CAS 674783-96-1
# ⚠️ Erreur pour le CAS nan : 'float' object is not iterable
# ✅ Informations ajoutées pour le CAS 8048-52-0
# ✅ Informations ajoutées pour le CAS 7152-42-3
# ⚠️ Erreur pour le CAS nan : 'float' object is not iterable

# %%
# Sauvegarder le fichier enrichi
data.to_csv(output_csv, sep=",", index=False)
print("\n✅ Fichier enrichi sauvegardé sous :", output_csv)
# Out:
# ✅ Fichier enrichi sauvegardé sous : photocompounds_database_pubchem.csv
